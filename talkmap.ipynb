# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Run this from the _talks/ directory, which contains .md files of all your talks. This scrapes the location YAML field from each .md file, geolocates it with geopy/Nominatim, and uses the getorg library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# !pip install getorg --upgrade
import glob
import getorg
import os
from geopy import Nominatim

# %%
os.chdir("/Users/richardanslow/Documents/Cambridge/richard17a.github.io/_talks")
g = glob.glob("*.md")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/richardanslow/Documents/Cambridge/richard17a.github.io/talkmap.ipynb Cell 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/richardanslow/Documents/Cambridge/richard17a.github.io/talkmap.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> os.chdir("./_talks/")
#       <a href='vscode-notebook-cell:/Users/richardanslow/Documents/Cambridge/richard17a.github.io/talkmap.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> g = glob.glob("*.md")
#
# FileNotFoundError: [Errno 2] No such file or directory: './_talks/'

# %%
os.getcwd()
# Out:
# '/Users/richardanslow/Documents/Cambridge/richard17a.github.io/_talks'

# %%
geocoder = Nominatim(user_agent="http")
location_dict = {}
location = ""
permalink = ""
title = ""

# %%
for file in g:
    with open(file, 'r') as f:
        lines = f.read()
        if lines.find('location: "') > 1:
            loc_start = lines.find('location: "') + 11
            lines_trim = lines[loc_start:]
            loc_end = lines_trim.find('"')
            location = lines_trim[:loc_end]
                            
           
        location_dict[location] = geocoder.geocode(location)
        print(location, "\n", location_dict[location])
# Out:
#
#  None
#
#  None
#
#  None
#
#  None

# %%
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="../talkmap", hashed_usernames=False)
# Out:
# 'Written map to ../talkmap/'
